# %% [markdown]
# # Records
#
# This section documents the progress of the research project through weekly meeting notes with the supervisor. Each meeting captures key discussions, decisions, and action items that guided the direction of the work.

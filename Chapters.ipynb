# %% [markdown]
# # Chapters
#
# Chapter content has been split into lighter, chapter-specific notebooks:
#
# - [Chapter 2](Chapter2.ipynb)
# - [Chapter 3](Chapter3.ipynb)
# - [Chapter 4](Chapter4.ipynb)
# - [Chapter 5](Chapter5.ipynb)
# - [Chapter 6](Chapter6.ipynb)

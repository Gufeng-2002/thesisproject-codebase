# %% [markdown]
# # Gallery
#
# A chronological showcase of every figure and tabular result generated by the
# chapter workflows. Items are grouped by **chapter** and **framework**, in the
# same order they appear in the analysis. Tables exported as `.xlsx` are linked
# for download below their caption.

# %% [markdown]
# # Chapter 2 — Pollution Assessment

# %% [markdown]
# ## Framework 1 — Composite Contamination Score (SumRel / MaxRel)
#
# PCA-based rotation of contaminant loadings is used to construct composite
# contamination scores. Empirical cumulative distributions identify
# reference vs. degraded site corridors.

# %% [markdown]
# ![SumRel corridor bifurcation](../codespace/figures/ch2_fm1_SumRel_corridor_bifurcation.png)
#
# **Figure 2.1.1** — *SumRel contamination score: ECDF bifurcation of the
# lowest- and most-polluted 62 sites across the Huron–St. Clair–Detroit
# corridor.*

# %% [markdown]
# ![MaxRel corridor bifurcation](../codespace/figures/ch2_fm1_MaxRel_corridor_bifurcation.png)
#
# **Figure 2.1.2** — *MaxRel contamination score: ECDF bifurcation of the
# extreme tails, isolating reference (green) and most-polluted (red) sites.*

# %% [markdown]
# <a class="table-download" href="../codespace/results/ch2_fw1_rotated_loading_table.xlsx" download>Download — Table 2.1.1: Rotated PCA Loadings</a>
#
# **Table 2.1.1** — *Varimax-rotated contaminant loadings used to derive the
# SumRel and MaxRel scores.*

# %% [markdown]
# ## Framework 2 — Resampling RDA & Empirical Validation
#
# Repeated RDA with subsampling probes the stability of taxa–environment
# associations and identifies the optimal cut-off for reference-site selection.

# %% [markdown]
# ![Adjusted R² by number of sites](../codespace/figures/ch2_fw2_extension_adj_R2_by_m.png)
#
# **Figure 2.2.1** — *Adjusted $R^2$ of Environmental / Stressor / SumRel
# predictors as a function of the number of sites passed to RDA fitting; the
# shaded band marks the reference-site cut-off range (46–77).*

# %% [markdown]
# ![Empirical distribution — adjusted R²](../codespace/figures/ch2_fw2_empirical_distribution_adj_R2.png)
#
# **Figure 2.2.2** — *Empirical distribution of adjusted $R^2$ under repeated
# resampling, providing a null reference for the observed signal.*

# %% [markdown]
# ![Empirical distribution — p-value](../codespace/figures/ch2_fw2_empirical_distribution_p_value.png)
#
# **Figure 2.2.3** — *Empirical distribution of permutation p-values for the
# resampled RDA models.*

# %% [markdown]
# <a class="table-download" href="../codespace/results/ch2_fw2_resampling_rda_results.xlsx" download>Download — Table 2.2.1: Resampling RDA Results</a>
#
# **Table 2.2.1** — *Per-replicate RDA summary statistics (adj. $R^2$, p-values,
# explained variance) for all resampling iterations.*

# %% [markdown]
# # Chapter 3 — Environmental Standardization

# %% [markdown]
# ## Framework 1 — Clustering of Reference Sites
#
# Hierarchical clustering on the 44 least-polluted sites, with approximately
# unbiased (AU) bootstrap support and node-wise ANOVA on environmental
# descriptors.

# %% [markdown]
# ![Ward dendrogram with AU support](../codespace/figures/ch3_fw1_cluster_dendrogram_AUs.png)
#
# **Figure 3.1.1** — *Ward dendrogram for the 44 least-polluted sites at $k=3$;
# AU bootstrap support is annotated for each cluster ($C_1 = 0.62$,
# $C_2 = 0.71$, $C_3 = 0.91$).*

# %% [markdown]
# ![Finalized cluster barplot](../codespace/figures/ch3_fw1_finalized_cluster_barplot.png)
#
# **Figure 3.1.2** — *Per-variable cluster means for the finalized three-cluster
# solution, highlighting the environmental contrast across $C_1$–$C_3$.*

# %% [markdown]
# <a class="table-download" href="results/ch3_fw1_pvclust_cluster_results.xlsx" download>Download — Table 3.1.1: pvclust Cluster Results</a>
#
# **Table 3.1.1** — *Bootstrap cluster assignments and AU / BP support values
# from the `pvclust` analysis.*

# %% [markdown]
# <a class="table-download" href="results/ch3_fw1_finalized_cluster_anova_table.xlsx" download>Download — Table 3.1.2: Finalized Cluster ANOVA</a>
#
# **Table 3.1.2** — *One-way ANOVA on environmental variables across the
# finalized three clusters.*

# %% [markdown]
# <a class="table-download" href="results/ch3_fw1_nodewise_anova_report.xlsx" download>Download — Table 3.1.3: Node-wise ANOVA Report</a>
#
# **Table 3.1.3** — *Node-by-node ANOVA along the dendrogram, identifying which
# splits separate environmentally distinct groups.*

# %% [markdown]
# ## Framework 2 — Env–Taxa Concordance
#
# Joint assessment of cluster membership in environmental and taxonomic space
# to extract concordant reference sites.

# %% [markdown]
# ![Concordance margin scatter](../codespace/figures/ch3_fw2_concordance_margin_scatter.png)
#
# **Figure 3.2.1** — *Consensus margins for the 60 least-polluted sites:
# environmental margin (own cluster vs. best alternative) plotted against the
# taxa margin; the upper-right quadrant marks concordant sites.*

# %% [markdown]
# ## Framework 3 — PCA Region Heatmaps & LDA Benchmark
#
# Probabilistic PCA region maps and discriminant analyses comparing the
# concordant subset against the full benchmark sample.

# %% [markdown]
# ![Concordant PCA region heatmap](../codespace/figures/ch3_fw3_concordant_pca_region_heatmap.png)
#
# **Figure 3.3.1** — *Finalized EnvStrong region map (PC1–PC2 and PC1–PC3) for
# the concordant reference sites; arrows show variable loadings.*

# %% [markdown]
# ![All-site PCA region heatmap](../codespace/figures/ch3_fw3_all_site_pca_region_heatmap.png)
#
# **Figure 3.3.2** — *Region map projected over all sites for comparison with
# the concordant-only model.*

# %% [markdown]
# <a class="table-download" href="../codespace/results/ch3_fw3_concordant_lda_stratified_confusion_matrix.xlsx" download>Download — Table 3.3.1: Concordant LDA (Stratified) Confusion Matrix</a>
#
# **Table 3.3.1** — *Stratified cross-validation confusion matrix for the LDA
# trained on the concordant reference set.*

# %% [markdown]
# <a class="table-download" href="../codespace/results/ch3_fw3_concordant_lda_random_split_cv_confusion_matrix.xlsx" download>Download — Table 3.3.2: Concordant LDA (Random Split CV)</a>
#
# **Table 3.3.2** — *Random-split cross-validation confusion matrix for the
# concordant LDA model.*

# %% [markdown]
# <a class="table-download" href="../codespace/results/ch3_fw3_benchmark_lda_stratified_confusion_matrix.xlsx" download>Download — Table 3.3.3: Benchmark LDA (Stratified)</a>
#
# **Table 3.3.3** — *Benchmark LDA confusion matrix (stratified CV) on the
# full sample, used as a comparison baseline.*

# %% [markdown]
# <a class="table-download" href="../codespace/results/ch3_fw3_benchmark_lda_random_split_cv_confusion_matrix.xlsx" download>Download — Table 3.3.4: Benchmark LDA (Random Split CV)</a>
#
# **Table 3.3.4** — *Benchmark LDA confusion matrix (random-split CV).*

# %% [markdown]
# # Chapter 4 — ZCI of Bray–Curtis Ordination on Community Composition

# %% [markdown]
# ## Framework 2 — NMDS Ordination & Pole Geometry
#
# Non-metric multidimensional scaling on Bray–Curtis dissimilarities, with
# stress diagnostics, Shepard fit, and pole-based ZCI construction.

# %% [markdown]
# ![Stress scree plot](../codespace/figures/ch4_framework2_stress_scree.png)
#
# **Figure 4.2.1** — *Stress vs. number of NMDS axes; the elbow informs the
# choice of dimensionality.*

# %% [markdown]
# ![Shepard diagrams](../codespace/figures/ch4_framework2_shepard_diagrams.png)
#
# **Figure 4.2.2** — *Shepard diagrams comparing observed Bray–Curtis distances
# to NMDS ordination distances; near-monotonic alignment confirms a good fit.*

# %% [markdown]
# ![Ordination panels](../codespace/figures/ch4_framework2_ordination_panels.png)
#
# **Figure 4.2.3** — *Final NMDS ordination panels colored by cluster
# membership, with pole markers used in the ZCI construction.*

# %% [markdown]
# <a class="table-download" href="../codespace/results/ch4_framework2_stress_profile.xlsx" download>Download — Table 4.2.1: Stress Profile</a>
#
# **Table 4.2.1** — *NMDS stress values across candidate dimensions.*

# %% [markdown]
# <a class="table-download" href="results/ch4_framework2_nmds_fit_summary.xlsx" download>Download — Table 4.2.2: NMDS Fit Summary</a>
#
# **Table 4.2.2** — *Summary of the finalized NMDS solution (stress, linear and
# non-metric $R^2$).*

# %% [markdown]
# <a class="table-download" href="results/ch4_framework2_pole_geometry.xlsx" download>Download — Table 4.2.3: Pole Geometry</a>
#
# **Table 4.2.3** — *Coordinates and pairwise distances for the cluster poles
# used to compute the Zoobenthic Community Index.*

# %% [markdown]
# <a class="table-download" href="results/ch4_framework2_residual_summary.xlsx" download>Download — Table 4.2.4: Residual Summary</a>
#
# **Table 4.2.4** — *Residual diagnostics for the NMDS fit.*
